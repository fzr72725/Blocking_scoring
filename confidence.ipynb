# %%
import pandas as pd
pd.set_option('display.max_colwidth', -1)
from fuzzywuzzy import fuzz, process
import string
import itertools
import numpy as np
import difflib

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /Users/zirufan/anaconda2/lib/python2.7/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#df_orig = pd.read_csv('data/csv_example_input_with_true_ids.csv')
df_orig = pd.read_csv('data/csv_example_output.csv')

# %%
df_orig.shape
# Out:
# (3337, 66)

# %%
df_orig.head(2)
# Out:
#    Cluster ID  confidence_score  Id                                 Source  \
# 0  0           0.993148          0   CPS_Early_Childhood_Portal_scrape.csv
# 1  0           0.993148          1   CPS_Early_Childhood_Portal_scrape.csv
#
#                                    Site name         Address  Zip      Phone  \
# 0   Salvation Army - Temple / Salvation Army  1 N Ogden Ave  NaN   2262649.0
# 1   Salvation Army - Temple / Salvation Army  1 N Ogden Ave  NaN   2262649.0
#
#    Fax Program Name      ...      canonical_Center Director  \
# 0  NaN  Child Care       ...       NaN
# 1  NaN  Child Care       ...       NaN
#
#   canonical_Funded Enrollment canonical_Column2 canonical_Number per Site EHS  \
# 0  salvation army              child care        NaN
# 1  salvation army              child care        NaN
#
#   canonical_Neighborhood canonical_Progmod canonical_IDHS Provider ID  \
# 0  near west side         no                NaN
# 1  near west side         no                NaN
#
#   canonical_Number per Site HS  canonical_Executive Director  canonical_Id
# 0  NaN                          NaN                           1.0
# 1  NaN                          NaN                           1.0
#
# [2 rows x 66 columns]

# %%
# Get entity blocks containing more than two records
record_cnt = df_orig.groupby('Cluster ID').size()
entity_ids = record_cnt[record_cnt > 2].index
# df_1 = df_orig.loc[df_orig['Cluster ID'].isin(entity_ids)].drop('confidence_score', axis=1)
df_1 = df_orig[df_orig.groupby('Cluster ID')['Cluster ID'].transform('size')>2]

# %% [markdown]
# ### Records are merged into entity groups identified by Cluster ID

# %%
df_1.sort_values('Cluster ID').head(15)
# Out:
#       Cluster ID  confidence_score    Id  \
# 0     0           0.993148          0
# 1226  0           0.993148          1226
# 1225  0           0.993148          1225
# 510   0           0.993148          510
# 509   0           0.993148          509
# 3255  0           0.969717          3255
# 215   0           0.987749          215
# 2758  0           0.985435          2758
# 1879  0           0.999547          1879
# 1     0           0.993148          1
# 3     2           0.993733          3
# 1228  2           0.993733          1228
# 1227  2           0.993733          1227
# 2     2           0.993733          2
# 216   2           0.962596          216
#
#                                      Source  \
# 0     CPS_Early_Childhood_Portal_scrape.csv
# 1226  CPS_Early_Childhood_Portal_scrape.csv
# 1225  CPS_Early_Childhood_Portal_scrape.csv
# 510   CPS_Early_Childhood_Portal_scrape.csv
# 509   CPS_Early_Childhood_Portal_scrape.csv
# 3255  purple_binder_early_childhood.csv
# 215   CPS_Early_Childhood_Portal_scrape.csv
# 2758  ECE Chicago Find a School scrape.csv
# 1879  chapin_dfss_providers_2011_070212.csv
# 1     CPS_Early_Childhood_Portal_scrape.csv
# 3     CPS_Early_Childhood_Portal_scrape.csv
# 1228  CPS_Early_Childhood_Portal_scrape.csv
# 1227  CPS_Early_Childhood_Portal_scrape.csv
# 2     CPS_Early_Childhood_Portal_scrape.csv
# 216   CPS_Early_Childhood_Portal_scrape.csv
#
#                                                             Site name  \
# 0      Salvation Army - Temple / Salvation Army
# 1226   Salvation Army - Temple / Salvation Army
# 1225   Salvation Army - Temple / Salvation Army
# 510    Salvation Army - Temple / Salvation Army
# 509    Salvation Army - Temple / Salvation Army
# 3255   Salvation Army - Chicago Temple Corps Community Center
# 215    Salvation Army Temple
# 2758   Salvation Army Temple
# 1879  SALVATION ARMY TEMPLE
# 1      Salvation Army - Temple / Salvation Army
# 3      National Louis University - Dr. Effie O. Ellis Training Center
# 1228   National Louis University - Dr. Effie O. Ellis Training Center
# 1227   National Louis University - Dr. Effie O. Ellis Training Center
# 2      National Louis University - Dr. Effie O. Ellis Training Center
# 216    National Louis University-Dr. Effie O. Ellis Head Start
#
#                 Address      Zip      Phone  Fax            Program Name  \
# 0     1 N Ogden Ave     NaN       2262649.0  NaN  Child Care
# 1226  1 N Ogden Ave     NaN       2262649.0  NaN  State Pre-Kindergarten
# 1225  1 N Ogden Ave     NaN       2262649.0  NaN  State Pre-Kindergarten
# 510   1 N Ogden Ave     NaN       2262649.0  NaN  Head Start
# 509   1 N Ogden Ave     NaN       2262649.0  NaN  Head Start
# 3255  1 N Ogden Avenue   60607.0  2262649.0  NaN  NaN
# 215   1 N. Ogden        NaN       2262649.0  NaN  Community Partnerships
# 2758  1 N. Ogden         60607.0  2262649.0  NaN  NaN
# 1879  1 N OGDEN          60640.0  2262649.0  NaN  NaN
# 1     1 N Ogden Ave     NaN       2262649.0  NaN  Child Care
# 3     10 S Kedzie Ave   NaN       5339011.0  NaN  Child Care
# 1228  10 S Kedzie Ave   NaN       5339011.0  NaN  State Pre-Kindergarten
# 1227  10 S Kedzie Ave   NaN       5339011.0  NaN  State Pre-Kindergarten
# 2     10 S Kedzie Ave   NaN       5339011.0  NaN  Child Care
# 216   10 S. Kedzie      NaN       5339011.0  NaN  Community Partnerships
#
#           ...      canonical_Center Director canonical_Funded Enrollment  \
# 0         ...       NaN                       salvation army
# 1226      ...       NaN                       salvation army
# 1225      ...       NaN                       salvation army
# 510       ...       NaN                       salvation army
# 509       ...       NaN                       salvation army
# 3255      ...       NaN                       salvation army
# 215       ...       NaN                       salvation army
# 2758      ...       NaN                       salvation army
# 1879      ...       NaN                       salvation army
# 1         ...       NaN                       salvation army
# 3         ...       NaN                       NaN
# 1228      ...       NaN                       NaN
# 1227      ...       NaN                       NaN
# 2         ...       NaN                       NaN
# 216       ...       NaN                       NaN
#
#      canonical_Column2 canonical_Number per Site EHS canonical_Neighborhood  \
# 0     child care        NaN                           near west side
# 1226  child care        NaN                           near west side
# 1225  child care        NaN                           near west side
# 510   child care        NaN                           near west side
# 509   child care        NaN                           near west side
# 3255  child care        NaN                           near west side
# 215   child care        NaN                           near west side
# 2758  child care        NaN                           near west side
# 1879  child care        NaN                           near west side
# 1     child care        NaN                           near west side
# 3     NaN               NaN                           NaN
# 1228  NaN               NaN                           NaN
# 1227  NaN               NaN                           NaN
# 2     NaN               NaN                           NaN
# 216   NaN               NaN                           NaN
#
#      canonical_Progmod canonical_IDHS Provider ID  \
# 0     no                NaN
# 1226  no                NaN
# 1225  no                NaN
# 510   no                NaN
# 509   no                NaN
# 3255  no                NaN
# 215   no                NaN
# 2758  no                NaN
# 1879  no                NaN
# 1     no                NaN
# 3     NaN               NaN
# 1228  NaN               NaN
# 1227  NaN               NaN
# 2     NaN               NaN
# 216   NaN               NaN
#
#      canonical_Number per Site HS  canonical_Executive Director  canonical_Id
# 0     NaN                          NaN                           1.0
# 1226  NaN                          NaN                           1.0
# 1225  NaN                          NaN                           1.0
# 510   NaN                          NaN                           1.0
# 509   NaN                          NaN                           1.0
# 3255  NaN                          NaN                           1.0
# 215   NaN                          NaN                           1.0
# 2758  NaN                          NaN                           1.0
# 1879  NaN                          NaN                           1.0
# 1     NaN                          NaN                           1.0
# 3     NaN                          NaN                           2.0
# 1228  NaN                          NaN                           2.0
# 1227  NaN                          NaN                           2.0
# 2     NaN                          NaN                           2.0
# 216   NaN                          NaN                           2.0
#
# [15 rows x 66 columns]

# %% [markdown]
# ### Customizable scoring fields

# %%
unique_comb = ['Site name','Address','Program Name']

# %%
def check_nan(df, cols):
    #print 'Dataframe total row count: ', df.shape[0]
    result = []
    for c in cols:
        if sum(df[c].isnull())>0:
            #print c , ' has ' , sum(df[c].isnull()) , 'null/NAN values'
            #nan_cnt += 1
            result.append(c)
    return result

# %%
def clean(my_string):
    # Remove punctuations
    # Convert to lower cases
    return my_string.lower()#.translate(None, string.punctuation)

# %% [markdown]
# ### Hefty scoing work is done in this function
# ### -- Unique value
# ###     -------- horizontal/vertical
# ### -- Pairwise comparison
# ###     -------- horizontal/vertical

# %%
# Apply to each entity group
def confidence(entity_group, solution, cols, weights=[0.4,0.2,0.4], axis=0):
    '''
    This function takes in a resolved/merged entity group, and generate
    a confidence score to indicate the uniformness of records in the group
    Note:
    Can't mix the score generating mechanism
    unique_val is indicating a rough proportion of unique values
    pair is indicating the fuzzy match score
    
    INPUT:
    entity_group: one entity group of merged records, type: pandas dataframe
    solution: score generating mechanism, type: string
    cols: selected record fields for score generating, type: string list
    weights: only used when axis=1, reflecting how important a column is, type: list
    axis: indicating row-wise or column-wise comparison, type: int
    
    OUTPUT:
    score: the confidence score, ranging from 0 to 1
    
    Example:
    confidence(entity_group, 'unique_vals', unique_comb)
    confidence(entity_group, 'unique_vals', unique_comb, axis=1)
    confidence(entity_group, 'pair', unique_comb
    '''
    total_records = entity_group.shape[0]
    # check nan cols
    non_cols = check_nan(entity_group, cols)
    #fill nan cols
    for nc in non_cols:
        entity_group.loc[:,nc]=entity_group[nc].fillna('VIA_filled')
    
    # Use unique value counts to generate confidence score
    if solution == 'unique_vals':
        result = []
        # read row by row
        if axis == 0:
            for idx, row in entity_group.iterrows():
                comb_str = []
                # call normalize function on each column
                # get a final combined string for the row
                for c in cols:
                    comb_str.append(clean(row[c]))
                # append the string to result set
                #print ''.join(comb_str)
                result.append(''.join(comb_str))
            # Here we use 1-score to unify the score range with pairwise comparison
            # so that the higher the score is, the more confident we are
            #score = 1 - len(set(result))*1./entity_group.shape[0]
            score = 1 if len(set(result))==1 else 1 - len(set(result))*1./entity_group.shape[0]
            
        elif axis == 1:
            # this score is very sensitive because it takes the exact column value
            # when counting unique counts for EACH column
            score = 0
            uniques = []
            for i, c in enumerate(cols):
                # unique count vs total row count in one column
                # weights can be customized
                #print entity_group[c].values
                uniques.append(len(set(entity_group[c].apply(lambda x: clean(x)).values)))
                score += uniques[-1]*1./entity_group.shape[0]*weights[i]
            score = 1 if sum(uniques)==len(cols) else 1 - score
    # Pairwise Levenshtein distance score via fuzzywuzzy
    elif solution == 'pair':
        # Same as unique_val, combining all fields into one string
        # to be the comparison unit
        scores = []
        if axis == 0:
            result = []
            for idx, row in entity_group.iterrows():
                comb_str = []
                for c in cols:
                    comb_str.append(clean(row[c]))
                result.append(''.join(comb_str))
            # Get all possible record pairs
            for i, j in itertools.combinations(result, 2):
                # ratio = (total_length - edit_distance)/total_length
                score = difflib.SequenceMatcher(None, i, j).ratio()
                scores.append(score)
                
            #score = (sum(scores)/(1.*len(scores)))/100
        # Generate vector of per column comparison
        elif axis == 1:
            # initialize result vector
            final_vector = np.zeros(len(cols))
            # Get all possible record pairs
            pair_cnt = 0
            for i, j in itertools.combinations(entity_group[cols].values, 2):
                pair_cnt += 1
                col_comp_vector = []
                # pairwise compare each col
                for idx, c in enumerate(cols):
                    score = difflib.SequenceMatcher(None, i[idx],j[idx]).ratio()
                    col_comp_vector.append(score)
                scores.append(sum([x*y for x,y in zip(col_comp_vector, weights)]))
                #final_vector += col_comp_vector
            #score = sum((final_vector/100/pair_cnt)*weights)
        score = min(scores)
            
    elif solution == 'semi-pair':
        pass
    
    #return round(score, 2)
    return score

# %%
def score_assign(entity_group, new_col, func, args):
    entity_group[new_col] = func(entity_group, *args)
    return entity_group

# %%
# Can't mix the score generating mechanism
# unique val is indicating a rough proportion of unique values, the lower the better
# pair is indicating the fuzzy match score, the higher the better
print 'Confidence score by unique row: \n', confidence(df_1[df_1['Cluster ID']==17], 'unique_vals', unique_comb)
print '\n'
print 'Confidence score by unique columns: \n', confidence(df_1[df_1['Cluster ID']==17], 'unique_vals', unique_comb, axis=1)
print '\n'
print 'Confidence score by pairwise comp: ', confidence(df_1[df_1['Cluster ID']==17], 'pair', unique_comb)
print '\n'
print 'Confidence score col-by-col by pairwise comp: ', confidence(df_1[df_1['Cluster ID']==17], 'pair', unique_comb, axis=1)
# Out:
# Confidence score by unique row:
# 0.0
#
#
# Confidence score by unique columns:
# 0.4
#
#
# Confidence score by pairwise comp:  0.868131868132
#
#
# Confidence score col-by-col by pairwise comp:  0.7

# %%
result_1 = df_1.groupby('Cluster ID').apply(score_assign, ('score1'), confidence, ['unique_vals', unique_comb])

# %%
result_2 = result_1.groupby('Cluster ID').apply(score_assign, ('score2'), confidence, ['unique_vals', unique_comb, [0.2, 0.4, 0.4],1])

# %%
result_3 = result_2.groupby('Cluster ID').apply(score_assign, ('score3'), confidence, ['pair', unique_comb, [0.2, 0.4, 0.4],1])

# %%
result_3.sort_values('Cluster ID')
# Out:
#       Cluster ID  confidence_score    Id  \
# 0     0           0.993148          0
# 1226  0           0.993148          1226
# 1225  0           0.993148          1225
# 510   0           0.993148          510
# 509   0           0.993148          509
# 3255  0           0.969717          3255
# 215   0           0.987749          215
# 2758  0           0.985435          2758
# 1879  0           0.999547          1879
# 1     0           0.993148          1
# 3     2           0.993733          3
# 1228  2           0.993733          1228
# 1227  2           0.993733          1227
# 2     2           0.993733          2
# 216   2           0.962596          216
# 512   2           0.993733          512
# 511   2           0.993733          511
# 514   4           0.866395          514
# 513   4           0.866395          513
# 4     4           0.866395          4
# 1926  4           0.987766          1926
# 5     4           0.866395          5
# 1408  4           0.980426          1408
# 2429  4           0.728973          2429
# 217   4           0.721097          217
# 2129  7           0.969585          2129
# 1230  7           0.991617          1230
# 1229  7           0.991617          1229
# 7     7           0.991617          7
# 1639  7           0.963588          1639
# ...  ..                ...           ...
# 408   806         0.756016          408
# 2230  806         0.987960          2230
# 3221  806         0.845997          3221
# 1750  808         0.757610          1750
# 1818  808         0.745646          1818
# 2232  808         0.745646          2232
# 857   808         0.733619          857
# 3256  815         0.999612          3256
# 1867  815         0.999842          1867
# 2261  815         0.999682          2261
# 2265  816         0.996835          2265
# 472   816         0.997386          472
# 1876  816         0.997734          1876
# 888   816         0.995714          888
# 883   818         0.995498          883
# 2274  818         0.995029          2274
# 1886  818         0.999271          1886
# 1896  820         0.999798          1896
# 710   820         0.999396          710
# 2284  820         0.999293          2284
# 3298  821         0.969881          3298
# 1903  821         0.998333          1903
# 1200  821         0.999165          1200
# 2291  821         0.971758          2291
# 1721  822         0.929113          1721
# 327   822         0.798758          327
# 2174  822         0.869559          2174
# 2644  826         0.987760          2644
# 2034  826         0.997688          2034
# 1540  826         0.989700          1540
#
#                                      Source  \
# 0     CPS_Early_Childhood_Portal_scrape.csv
# 1226  CPS_Early_Childhood_Portal_scrape.csv
# 1225  CPS_Early_Childhood_Portal_scrape.csv
# 510   CPS_Early_Childhood_Portal_scrape.csv
# 509   CPS_Early_Childhood_Portal_scrape.csv
# 3255  purple_binder_early_childhood.csv
# 215   CPS_Early_Childhood_Portal_scrape.csv
# 2758  ECE Chicago Find a School scrape.csv
# 1879  chapin_dfss_providers_2011_070212.csv
# 1     CPS_Early_Childhood_Portal_scrape.csv
# 3     CPS_Early_Childhood_Portal_scrape.csv
# 1228  CPS_Early_Childhood_Portal_scrape.csv
# 1227  CPS_Early_Childhood_Portal_scrape.csv
# 2     CPS_Early_Childhood_Portal_scrape.csv
# 216   CPS_Early_Childhood_Portal_scrape.csv
# 512   CPS_Early_Childhood_Portal_scrape.csv
# 511   CPS_Early_Childhood_Portal_scrape.csv
# 514   CPS_Early_Childhood_Portal_scrape.csv
# 513   CPS_Early_Childhood_Portal_scrape.csv
# 4     CPS_Early_Childhood_Portal_scrape.csv
# 1926  DFSS_AgencySiteLies_2012.csv
# 5     CPS_Early_Childhood_Portal_scrape.csv
# 1408  chapin_dfss_providers_2011_070212.csv
# 2429  ECE Chicago Find a School scrape.csv
# 217   CPS_Early_Childhood_Portal_scrape.csv
# 2129  DFSS_AgencySiteLies_2012.csv
# 1230  CPS_Early_Childhood_Portal_scrape.csv
# 1229  CPS_Early_Childhood_Portal_scrape.csv
# 7     CPS_Early_Childhood_Portal_scrape.csv
# 1639  chapin_dfss_providers_2011_070212.csv
# ...                                     ...
# 408   CPS_Early_Childhood_Portal_scrape.csv
# 2230  DFSS_AgencySiteLies_2012.csv
# 3221  purple_binder_early_childhood.csv
# 1750  chapin_dfss_providers_2011_070212.csv
# 1818  chapin_dfss_providers_2011_070212.csv
# 2232  DFSS_AgencySiteLies_2012.csv
# 857   CPS_Early_Childhood_Portal_scrape.csv
# 3256  purple_binder_early_childhood.csv
# 1867  chapin_dfss_providers_2011_070212.csv
# 2261  DFSS_AgencySiteLies_2012.csv
# 2265  DFSS_AgencySiteLies_2012.csv
# 472   CPS_Early_Childhood_Portal_scrape.csv
# 1876  chapin_dfss_providers_2011_070212.csv
# 888   CPS_Early_Childhood_Portal_scrape.csv
# 883   CPS_Early_Childhood_Portal_scrape.csv
# 2274  DFSS_AgencySiteLies_2012.csv
# 1886  chapin_dfss_providers_2011_070212.csv
# 1896  chapin_dfss_providers_2011_070212.csv
# 710   CPS_Early_Childhood_Portal_scrape.csv
# 2284  DFSS_AgencySiteLies_2012.csv
# 3298  purple_binder_early_childhood.csv
# 1903  chapin_dfss_providers_2011_070212.csv
# 1200  CPS_Early_Childhood_Portal_scrape.csv
# 2291  DFSS_AgencySiteLies_2012.csv
# 1721  chapin_dfss_providers_2011_070212.csv
# 327   CPS_Early_Childhood_Portal_scrape.csv
# 2174  DFSS_AgencySiteLies_2012.csv
# 2644  ECE Chicago Find a School scrape.csv
# 2034  DFSS_AgencySiteLies_2012.csv
# 1540  chapin_dfss_providers_2011_070212.csv
#
#                                                                Site name  \
# 0      Salvation Army - Temple / Salvation Army
# 1226   Salvation Army - Temple / Salvation Army
# 1225   Salvation Army - Temple / Salvation Army
# 510    Salvation Army - Temple / Salvation Army
# 509    Salvation Army - Temple / Salvation Army
# 3255   Salvation Army - Chicago Temple Corps Community Center
# 215    Salvation Army Temple
# 2758   Salvation Army Temple
# 1879  SALVATION ARMY TEMPLE
# 1      Salvation Army - Temple / Salvation Army
# 3      National Louis University - Dr. Effie O. Ellis Training Center
# 1228   National Louis University - Dr. Effie O. Ellis Training Center
# 1227   National Louis University - Dr. Effie O. Ellis Training Center
# 2      National Louis University - Dr. Effie O. Ellis Training Center
# 216    National Louis University-Dr. Effie O. Ellis Head Start
# 512    National Louis University - Dr. Effie O. Ellis Training Center
# 511    National Louis University - Dr. Effie O. Ellis Training Center
# 514    Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 513    Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 4      Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 1926  Board Trustees-City\nColleges of Chicago Olive-Harvey College
# 5      Board Trustees-City Colleges of Chicago - Olive-Harvey College
# 1408  BOARD TRUSTEES-CITY COLLEGES OF CHICAGO OLIVE-HARVEY COLLEGE
# 2429   City Colleges Olive Harvey
# 217    City Colleges Olive-Harvey CDC
# 2129  Easter Seals Society of Metropolitan Chicago Gilchrist Marchman
# 1230   Easter Seals Society of Metropolitan Chicago - Gilchrist-Marchman
# 1229   Easter Seals Society of Metropolitan Chicago - Gilchrist-Marchman
# 7      Easter Seals Society of Metropolitan Chicago - Gilchrist-Marchman
# 1639  EASTER SEALS SOCIETY OF METROPOLITAN CHICAGO GILCHRIST MARCHMAN
# ...                                                               ...
# 408    Marcy-Newberry Austin Town Hall
# 2230  Marcy Newberry Association Austin Town Hall
# 3221   Marcy Newberry Association - Austin Town Hall
# 1750  HENRY BOOTH HOUSE LEARNING TREE
# 1818  MARCY NEWBERRY ASSOCIATION LEARNING TREE 1
# 2232  Marcy Newberry Association Learning Tree 1
# 857    Henry Booth House - Learning Tree
# 3256   Salvation Army - Edsel Albert Ammons Nursery
# 1867  SALVATION ARMY EDSEL ALBERT AMMONS NURSERY
# 2261  Salvation Army Edsel Albert Ammons Nursery
# 2265  Salvation Army Red Shield
# 472    Salvation Army Red Shield
# 1876  SALVATION ARMY RED SHIELD
# 888    Salvation Army - Red Shield
# 883    Trinity Resources Unlimited, Inc. - High Mountain
# 2274  Trinity Resources Unlimited Inc High Mountain
# 1886  TRINITY RESOURCES UNLIMITED, INC. HIGH MOUNTAIN
# 1896  YMCA OF METROPOLITAN CHICAGO LOGAN SQUARE - FIRST LUTHERAN
# 710    YMCA of Metropolitan Chicago - Logan Square - First Lutheran YMCA
# 2284  YMCA of Metropolitan Chicago Logan Square - First Lutheran
# 3298   YMCA Wabash
# 1903  YMCA OF METROPOLITAN CHICAGO WABASH
# 1200   YMCA of Metropolitan Chicago - Wabash YMCA
# 2291  YMCA of Metropolitan Chicago Wabash
# 1721  GADS HILL CENTER KOVE LEARNING ACADEMY
# 327    Kove Learning Academy
# 2174  Gads Hill Center Kove Learning Academy
# 2644   Mason
# 2034  Chicago Public Schools Mason, Roswell B.
# 1540  CHICAGO PUBLIC SCHOOLS MASON, ROSWELL B.
#
#                        Address      Zip      Phone  Fax  \
# 0     1 N Ogden Ave            NaN       2262649.0  NaN
# 1226  1 N Ogden Ave            NaN       2262649.0  NaN
# 1225  1 N Ogden Ave            NaN       2262649.0  NaN
# 510   1 N Ogden Ave            NaN       2262649.0  NaN
# 509   1 N Ogden Ave            NaN       2262649.0  NaN
# 3255  1 N Ogden Avenue          60607.0  2262649.0  NaN
# 215   1 N. Ogden               NaN       2262649.0  NaN
# 2758  1 N. Ogden                60607.0  2262649.0  NaN
# 1879  1 N OGDEN                 60640.0  2262649.0  NaN
# 1     1 N Ogden Ave            NaN       2262649.0  NaN
# 3     10 S Kedzie Ave          NaN       5339011.0  NaN
# 1228  10 S Kedzie Ave          NaN       5339011.0  NaN
# 1227  10 S Kedzie Ave          NaN       5339011.0  NaN
# 2     10 S Kedzie Ave          NaN       5339011.0  NaN
# 216   10 S. Kedzie             NaN       5339011.0  NaN
# 512   10 S Kedzie Ave          NaN       5339011.0  NaN
# 511   10 S Kedzie Ave          NaN       5339011.0  NaN
# 514   10001 S Woodlawn Ave     NaN       2916100.0  NaN
# 513   10001 S Woodlawn Ave     NaN       2916100.0  NaN
# 4     10001 S Woodlawn Ave     NaN       2916100.0  NaN
# 1926  10001 S. Woodlawn         60628.0  2916317.0  NaN
# 5     10001 S Woodlawn Ave     NaN       2916100.0  NaN
# 1408  10001 S WOODLAWN          60628.0  2916317.0  NaN
# 2429  10001 S. Woodlawn         60628.0  2916315.0  NaN
# 217   10001 S. Woodlawn        NaN       2916315.0  NaN
# 2129  1001 W Roosevelt Rd       60608.0  4927402.0  NaN
# 1230  1001 W Roosevelt Rd      NaN       9395115.0  NaN
# 1229  1001 W Roosevelt Rd      NaN       9395115.0  NaN
# 7     1001 W Roosevelt Rd      NaN       9395115.0  NaN
# 1639  1001 W ROOSEVELT RD 606   81559.0  4927402.0  NaN
# ...                        ...      ...        ...  ...
# 408   5610 W. Lake St.         NaN       2611062.0  NaN
# 2230  5610 W. Lake              60644.0  2611505.0  NaN
# 3221  5610 W Lake Street        60644.0  2611505.0  NaN
# 1750  8128 S KEDZIE             60652.0  7788802.0  NaN
# 1818  8128 S KEDZIE             60652.0  7788802.0  NaN
# 2232  8128 S Kedzie             60652.0  7788802.0  NaN
# 857   8128 S Kedzie Ave        NaN       7788802.0  NaN
# 3256  549 E 76th Street         60619.0  4837040.0  NaN
# 1867  549 E 76TH ST             60619.0  4837040.0  NaN
# 2261  549 E 76th St.            60619.0  4837040.0  NaN
# 2265  945 W. 69th St.           60621.0  3583224.0  NaN
# 472   945 W. 69th St.          NaN       3583224.0  NaN
# 1876  945 W 69TH STREET         60621.0  3583224.0  NaN
# 888   945 W 69th St            NaN       3583203.0  NaN
# 883   919 N Lavergne Ave       NaN       6263994.0  NaN
# 2274  919 N. Lavergne           60651.0  6263997.0  NaN
# 1886  919 N LAVERGNE            60651.0  6263997.0  NaN
# 1896  3500 W FULLERTON          60647.0  8625960.0  NaN
# 710   3500 W Fullerton Ave     NaN       8625960.0  NaN
# 2284  3500 W. Fullerton         60647.0  8625960.0  NaN
# 3298  3763 S Wabash Avenue      60653.0  2850020.0  NaN
# 1903  3763 S WABASH AVE         60653.0  2850020.0  NaN
# 1200  3763 S Wabash Ave        NaN       2850020.0  NaN
# 2291  3763 S. Wabash Ave.       60653.0  2850020.0  NaN
# 1721  3137 W 71ST ST            60629.0  4763083.0  NaN
# 327   3137 W. 71st Street      NaN       4763083.0  NaN
# 2174  3137 W 71st St.           60629.0  4763083.0  NaN
# 2644  4216 W. 19th St.          60623.0  5341530.0  NaN
# 2034  4216 W. 19th St           60623.0  5341530.0  NaN
# 1540  4216 W 19TH ST            60623.0  5341530.0  NaN
#
#                 Program Name    ...    canonical_Number per Site EHS  \
# 0     Child Care                ...     NaN
# 1226  State Pre-Kindergarten    ...     NaN
# 1225  State Pre-Kindergarten    ...     NaN
# 510   Head Start                ...     NaN
# 509   Head Start                ...     NaN
# 3255  VIA_filled                ...     NaN
# 215   Community Partnerships    ...     NaN
# 2758  VIA_filled                ...     NaN
# 1879  VIA_filled                ...     NaN
# 1     Child Care                ...     NaN
# 3     Child Care                ...     NaN
# 1228  State Pre-Kindergarten    ...     NaN
# 1227  State Pre-Kindergarten    ...     NaN
# 2     Child Care                ...     NaN
# 216   Community Partnerships    ...     NaN
# 512   Head Start                ...     NaN
# 511   Head Start                ...     NaN
# 514   Head Start                ...     NaN
# 513   Head Start                ...     NaN
# 4     Child Care                ...     NaN
# 1926  VIA_filled                ...     NaN
# 5     Child Care                ...     NaN
# 1408  VIA_filled                ...     NaN
# 2429  VIA_filled                ...     NaN
# 217   Community Partnerships    ...     NaN
# 2129  VIA_filled                ...     NaN
# 1230  State Pre-Kindergarten    ...     NaN
# 1229  State Pre-Kindergarten    ...     NaN
# 7     Child Care                ...     NaN
# 1639  VIA_filled                ...     NaN
# ...          ...                ...     ...
# 408   Community Partnerships    ...     NaN
# 2230  VIA_filled                ...     NaN
# 3221  VIA_filled                ...     NaN
# 1750  VIA_filled                ...     NaN
# 1818  VIA_filled                ...     NaN
# 2232  VIA_filled                ...     NaN
# 857   Head Start                ...     NaN
# 3256  VIA_filled                ...     NaN
# 1867  VIA_filled                ...     NaN
# 2261  VIA_filled                ...     NaN
# 2265  VIA_filled                ...     NaN
# 472   Community Partnerships    ...     NaN
# 1876  VIA_filled                ...     NaN
# 888   Head Start                ...     NaN
# 883   Head Start                ...     NaN
# 2274  VIA_filled                ...     NaN
# 1886  VIA_filled                ...     NaN
# 1896  VIA_filled                ...     NaN
# 710   Head Start                ...     NaN
# 2284  VIA_filled                ...     NaN
# 3298  VIA_filled                ...     NaN
# 1903  VIA_filled                ...     NaN
# 1200  School Age                ...     NaN
# 2291  VIA_filled                ...     NaN
# 1721  VIA_filled                ...     NaN
# 327   Community Partnerships    ...     NaN
# 2174  VIA_filled                ...     NaN
# 2644  VIA_filled                ...     NaN
# 2034  VIA_filled                ...     NaN
# 1540  VIA_filled                ...     NaN
#
#      canonical_Neighborhood canonical_Progmod canonical_IDHS Provider ID  \
# 0     near west side         no                NaN
# 1226  near west side         no                NaN
# 1225  near west side         no                NaN
# 510   near west side         no                NaN
# 509   near west side         no                NaN
# 3255  near west side         no                NaN
# 215   near west side         no                NaN
# 2758  near west side         no                NaN
# 1879  near west side         no                NaN
# 1     near west side         no                NaN
# 3     NaN                    NaN               NaN
# 1228  NaN                    NaN               NaN
# 1227  NaN                    NaN               NaN
# 2     NaN                    NaN               NaN
# 216   NaN                    NaN               NaN
# 512   NaN                    NaN               NaN
# 511   NaN                    NaN               NaN
# 514   pullman                no                NaN
# 513   pullman                no                NaN
# 4     pullman                no                NaN
# 1926  pullman                no                NaN
# 5     pullman                no                NaN
# 1408  pullman                no                NaN
# 2429  pullman                no                NaN
# 217   pullman                no                NaN
# 2129  NaN                    yes               NaN
# 1230  NaN                    yes               NaN
# 1229  NaN                    yes               NaN
# 7     NaN                    yes               NaN
# 1639  NaN                    yes               NaN
# ...   ...                    ...               ...
# 408   austin                 no                NaN
# 2230  austin                 no                NaN
# 3221  austin                 no                NaN
# 1750  NaN                    no                NaN
# 1818  NaN                    no                NaN
# 2232  NaN                    no                NaN
# 857   NaN                    no                NaN
# 3256  NaN                    no                NaN
# 1867  NaN                    no                NaN
# 2261  NaN                    no                NaN
# 2265  NaN                    no                NaN
# 472   NaN                    no                NaN
# 1876  NaN                    no                NaN
# 888   NaN                    no                NaN
# 883   NaN                    no                NaN
# 2274  NaN                    no                NaN
# 1886  NaN                    no                NaN
# 1896  NaN                    no                NaN
# 710   NaN                    no                NaN
# 2284  NaN                    no                NaN
# 3298  NaN                    no                NaN
# 1903  NaN                    no                NaN
# 1200  NaN                    no                NaN
# 2291  NaN                    no                NaN
# 1721  NaN                    no                NaN
# 327   NaN                    no                NaN
# 2174  NaN                    no                NaN
# 2644  north lawndale         no                NaN
# 2034  north lawndale         no                NaN
# 1540  north lawndale         no                NaN
#
#      canonical_Number per Site HS  \
# 0     NaN
# 1226  NaN
# 1225  NaN
# 510   NaN
# 509   NaN
# 3255  NaN
# 215   NaN
# 2758  NaN
# 1879  NaN
# 1     NaN
# 3     NaN
# 1228  NaN
# 1227  NaN
# 2     NaN
# 216   NaN
# 512   NaN
# 511   NaN
# 514   NaN
# 513   NaN
# 4     NaN
# 1926  NaN
# 5     NaN
# 1408  NaN
# 2429  NaN
# 217   NaN
# 2129  NaN
# 1230  NaN
# 1229  NaN
# 7     NaN
# 1639  NaN
# ...   ...
# 408   NaN
# 2230  NaN
# 3221  NaN
# 1750  NaN
# 1818  NaN
# 2232  NaN
# 857   NaN
# 3256  NaN
# 1867  NaN
# 2261  NaN
# 2265  NaN
# 472   NaN
# 1876  NaN
# 888   NaN
# 883   NaN
# 2274  NaN
# 1886  NaN
# 1896  NaN
# 710   NaN
# 2284  NaN
# 3298  NaN
# 1903  NaN
# 1200  NaN
# 2291  NaN
# 1721  NaN
# 327   NaN
# 2174  NaN
# 2644  NaN
# 2034  NaN
# 1540  NaN
#
#                                       canonical_Executive Director  \
# 0     NaN
# 1226  NaN
# 1225  NaN
# 510   NaN
# 509   NaN
# 3255  NaN
# 215   NaN
# 2758  NaN
# 1879  NaN
# 1     NaN
# 3     NaN
# 1228  NaN
# 1227  NaN
# 2     NaN
# 216   NaN
# 512   NaN
# 511   NaN
# 514   7056ps(hs collaboration with childcare & prek)
# 513   7056ps(hs collaboration with childcare & prek)
# 4     7056ps(hs collaboration with childcare & prek)
# 1926  7056ps(hs collaboration with childcare & prek)
# 5     7056ps(hs collaboration with childcare & prek)
# 1408  7056ps(hs collaboration with childcare & prek)
# 2429  7056ps(hs collaboration with childcare & prek)
# 217   7056ps(hs collaboration with childcare & prek)
# 2129  4249it(child care it center), 7012ps(hs collaboration with c
# 1230  4249it(child care it center), 7012ps(hs collaboration with c
# 1229  4249it(child care it center), 7012ps(hs collaboration with c
# 7     4249it(child care it center), 7012ps(hs collaboration with c
# 1639  4249it(child care it center), 7012ps(hs collaboration with c
# ...                                                            ...
# 408   7028ps(hs collaboration with childcare & prek), 4155ps(child
# 2230  7028ps(hs collaboration with childcare & prek), 4155ps(child
# 3221  7028ps(hs collaboration with childcare & prek), 4155ps(child
# 1750  NaN
# 1818  NaN
# 2232  NaN
# 857   NaN
# 3256  NaN
# 1867  NaN
# 2261  NaN
# 2265  NaN
# 472   NaN
# 1876  NaN
# 888   NaN
# 883   NaN
# 2274  NaN
# 1886  NaN
# 1896  NaN
# 710   NaN
# 2284  NaN
# 3298  2133sa(school age (sa))
# 1903  2133sa(school age (sa))
# 1200  2133sa(school age (sa))
# 2291  2133sa(school age (sa))
# 1721  NaN
# 327   NaN
# 2174  NaN
# 2644  NaN
# 2034  NaN
# 1540  NaN
#
#      canonical_Id    score1    score2    score3
# 0     1.0          0.300000  0.560000  0.282258
# 1226  1.0          0.300000  0.560000  0.282258
# 1225  1.0          0.300000  0.560000  0.282258
# 510   1.0          0.300000  0.560000  0.282258
# 509   1.0          0.300000  0.560000  0.282258
# 3255  1.0          0.300000  0.560000  0.282258
# 215   1.0          0.300000  0.560000  0.282258
# 2758  1.0          0.300000  0.560000  0.282258
# 1879  1.0          0.300000  0.560000  0.282258
# 1     1.0          0.300000  0.560000  0.282258
# 3     2.0          0.428571  0.600000  0.567379
# 1228  2.0          0.428571  0.600000  0.567379
# 1227  2.0          0.428571  0.600000  0.567379
# 2     2.0          0.428571  0.600000  0.567379
# 216   2.0          0.428571  0.600000  0.567379
# 512   2.0          0.428571  0.600000  0.567379
# 511   2.0          0.428571  0.600000  0.567379
# 514   5.0          0.250000  0.525000  0.322527
# 513   5.0          0.250000  0.525000  0.322527
# 4     5.0          0.250000  0.525000  0.322527
# 1926  5.0          0.250000  0.525000  0.322527
# 5     5.0          0.250000  0.525000  0.322527
# 1408  5.0          0.250000  0.525000  0.322527
# 2429  5.0          0.250000  0.525000  0.322527
# 217   5.0          0.250000  0.525000  0.322527
# 2129  6.0          0.400000  0.680000  0.290310
# 1230  6.0          0.400000  0.680000  0.290310
# 1229  6.0          0.400000  0.680000  0.290310
# 7     6.0          0.400000  0.680000  0.290310
# 1639  6.0          0.400000  0.680000  0.290310
# ...   ...               ...       ...       ...
# 408   2230.0       0.000000  0.333333  0.340943
# 2230  2230.0       0.000000  0.333333  0.340943
# 3221  2230.0       0.000000  0.333333  0.340943
# 1750  1750.0       0.250000  0.450000  0.336579
# 1818  1750.0       0.250000  0.450000  0.336579
# 2232  1750.0       0.250000  0.450000  0.336579
# 857   1750.0       0.250000  0.450000  0.336579
# 3256  2261.0       0.000000  0.333333  0.725575
# 1867  2261.0       0.000000  0.333333  0.725575
# 2261  2261.0       0.000000  0.333333  0.725575
# 2265  888.0        0.000000  0.250000  0.324510
# 472   888.0        0.000000  0.250000  0.324510
# 1876  888.0        0.000000  0.250000  0.324510
# 888   888.0        0.000000  0.250000  0.324510
# 883   883.0        0.000000  0.133333  0.321844
# 2274  883.0        0.000000  0.133333  0.321844
# 1886  883.0        0.000000  0.133333  0.321844
# 1896  710.0        0.000000  0.200000  0.333990
# 710   710.0        0.000000  0.200000  0.333990
# 2284  710.0        0.000000  0.200000  0.333990
# 3298  1200.0       0.000000  0.350000  0.385983
# 1903  1200.0       0.000000  0.350000  0.385983
# 1200  1200.0       0.000000  0.350000  0.385983
# 2291  1200.0       0.000000  0.350000  0.385983
# 1721  327.0        0.000000  0.200000  0.364286
# 327   327.0        0.000000  0.200000  0.364286
# 2174  327.0        0.000000  0.200000  0.364286
# 2644  2644.0       0.000000  0.333333  0.717391
# 2034  2644.0       0.000000  0.333333  0.717391
# 1540  2644.0       0.000000  0.333333  0.717391
#
# [1891 rows x 69 columns]
